# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data.csv")
print("importing data sucessfully")
# Out:
# importing data sucessfully

# %%
print("printing first 5 data of Data.set")
data.head(10)
# Out:
# printing first 5 data of Data.set
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
print("data imported successfully")
# Out:
# data imported successfully

# %%
data.plot(x='Hours',y='Scores',style='1')
plt.title('Hours v/s Percentages')
plt.xlabel('Study Hours')
plt.ylabel('percentage Score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data.plot(x='Hours',y='Scores',style='1')
#       2 plt.title('Hours v/s Percentages')
#       3 plt.xlabel('Study Hours')
#
# NameError: name 'data' is not defined

# %%
data.plot.pie(x='Hours',y='Scores')
# Out:
# <Axes: ylabel='Scores'>

# %%
data.plot.scatter(x='Hours',y='Scores')
# Out:
# <Axes: xlabel='Hours', ylabel='Scores'>

# %%
data.plot.bar(x='Hours',y='Scores')
# Out:
# <Axes: xlabel='Hours'>

# %%
data.sort_values(["Hours"],axis=0,
                ascending=[True],inplace=True)
data.head(10)
data.plot.bar(x='Hours',y='Scores')
# Out:
# <Axes: xlabel='Hours'>

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:,1].values
# print(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y,
                                                    test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor =  LinearRegression()
# from sklearn.ensemble import RandomForestRegressor
# regressor = RandomForestRegressor(n_estimations =1000, random_state =42)
regressor.fit(x_train, y_train)
print("training complete.")
# Out:
# training complete.

# %%
print(x_test)
print('predection of score')
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [[3.2]
#  [3.8]
#  [4.5]
#  [8.9]
#  [1.5]
#  [2.7]]
# predection of score
# [34.79809536 40.58269669 47.33139825 89.75180801 18.40839159 29.97759425]

# %%
df = pd.DataFrame({'actual':y_test, 'predicted':y_pred})
df
# Out:
#    actual  predicted
# 0      27  34.798095
# 1      35  40.582697
# 2      41  47.331398
# 3      95  89.751808
# 4      20  18.408392
# 5      25  29.977594

# %%
hours = [[9.25]]
pred = regressor.predict(hours)
print(pred)
# Out:
# [93.12615879]

# %%
from sklearn  import metrics
print('mean absolute error:',
      metrics.mean_absolute_error(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from sklearn  import matrics
#       2 print('mean absolute error:',
#       3       matrics.mean_absolute_error(y_test,y_pred))
#
# ImportError: cannot import name 'matrics' from 'sklearn' (C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\__init__.py)
